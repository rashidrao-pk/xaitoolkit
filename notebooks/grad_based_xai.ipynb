# %% [markdown]
# # xaitoolkit — Gradient-based XAI on a CNN
#
# This notebook shows how to:
# 1) Load a pretrained CNN (ResNet-50).
# 2) Run inference on one image.
# 3) Generate gradient-based explanations using **xaitoolkit**:
#    - Saliency
#    - SmoothGrad
#    - Integrated Gradients
# 4) Visualize: input + top-5 probabilities + explanations.

# %% [markdown]
# > If you want to install from PyPI:

# %%
# %pip install -q xaitoolkit
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
## Install from Github Repo
# %pip install -q -e ..

# %%
import os
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
from PIL import Image

import xaitoolkit

# %%
import xaitoolkit, pkgutil
[m.name for m in pkgutil.iter_modules(xaitoolkit.__path__)]
# Out:
# ['cli', 'loaders', 'methods', 'utils']
